# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import pickle
import csv
import numpy as np
import pandas as pd
from learner.skipgram import Vocab

# %%
with open('../../models/fragment-based-dgm/DATA/CHEMBL/PROCESSED/train.smi', 'r') as f:
    data = list(csv.reader(f, delimiter=","))
data = np.array(data)

# %%
df = pd.DataFrame(data = data[1:,],  
                        columns = data[0,:])

# %%
df
# Out:
#                                                            smiles  \
# 0            0  CCCN(CCc1cccc(-c2ccccc2)c1)C(=O)C1OC(C(=O)O)=C...
# 1            1        Oc1ccc(C2CC(c3ccccc3)=NN2C(=S)Nc2ccccc2)cc1
# 2            2  COC(=O)c1cc(C(=CCCCC(=O)SC)c2cc(Cl)c(OC)c(C(=O...
# 3            3  Cc1cc(COc2ccc(NC(=O)C3CN(C)CCC3C(=O)NO)cc2)c2c...
# 4            4  CCOC(=O)c1ccc(O)c(-n2cc3c(c2-c2ccccc2)c(=O)n(C...
# ...        ...                                                ...
# 103486  114539  COc1ccccc1N1CCN(CCCNC(=O)C2CCCN(c3ncnc4c3nc3n4...
# 103487  114540  O=C(COc1ccccc1N=Nc1ccccc1OCC(=O)NC(Cc1ccccc1)C...
# 103488  114541  CN(C)S(=O)(=O)c1ccc(Cl)c(NC(=O)CN2C(=O)NC3(CCC...
# 103489  114542        O=C(Nc1ccc(OC(F)(F)F)cc1)N1CCN(c2cccnn2)CC1
# 103490  114543  Cc1ccc(F)cc1C(=O)Nc1ccc(C(=O)N2Cc3sccc3Cc3cccc...
#
#                                                 fragments n_fragments   C  F  \
# 0       *CCC *N(CCc1cccc(-c2ccccc2)c1)C(=O)C1OC(C(=O)O...           2  26  0
# ...

# %%
vocab_cls = Vocab(df)
# Out:
# Training and clustering embeddings...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 vocab_cls = Vocab(df)
#
# File ~/UCL/drug_discovery/fragment-vae/learner/skipgram.py:18, in Vocab.__init__(self, data)
#      17 def __init__(self, data):
# ---> 18     w2i, i2w, w2v, i2w_infreq, w2w_infreq, c2w_infreq = train_embeddings(data)
#      19     self.w2i = w2i
#      20     self.i2w = i2w
#
# File ~/UCL/drug_discovery/fragment-vae/learner/skipgram.py:93, in train_embeddings(data)
#      90 i2w = {v: k for (k, v) in w2i.items()}
#      92 # get infrequent indices into a list
# ---> 93 infreq = [w2i[w] for (w, freq) in w2f.items() if freq <= mask_freq]
#      95 # generate a dictionary of infrequent words according to the count
#      96 i2w_infreq = {}
#
# File ~/UCL/drug_discovery/fragment-vae/learner/skipgram.py:93, in <listcomp>(.0)
# ...

# %%
debug
# Out:
# > /home/teddy_t/UCL/drug_discovery/fragment-vae/learner/skipgram.py(92)<listcomp>()
#      90
#      91         # get infrequent indices into a list
# ---> 92         infreq = [w2i[w] for (w, freq) in w2f.items() if freq <= mask_freq]
#      93
#      94         # generate a dictionary of infrequent words according to the count
#
# ipdb> w
#   <ipython-input-6-e9e85e10a4aa>(1)<cell line: 1>()
# ----> 1 vocab_cls = Vocab(df)
#
#   /home/teddy_t/UCL/drug_discovery/fragment-vae/learner/skipgram.py(18)__init__()
#      16 class Vocab:
#      17     def __init__(self, data):
# ---> 18         w2i, i2w, w2v, i2w_infreq, w2w_infreq, c2w_infreq = train_embeddings(data)
#      19         self.w2i = w2i
#      20         self.i2w = i2w
#
#   /home/teddy_t/UCL/drug_discovery/fragment-vae/learner/skipgram.py(92)train_embeddings()
#      90
#      91         # get infrequent indices into a list
# ---> 92         infreq = [w2i[w] for (w, freq) in w2f.items() if freq <= mask_freq]
#      93
# ...

# %%
vocab_cls.c2w_infreq

# %%
vocab_cls.w2v.wv.vectors.shape
# Out:
# (107608, 64)

# %%
my_dict = dict({})
for idx, key in enumerate(vocab_cls.w2v.wv.vocab):
    my_dict[key] = model.wv[key]
    # Or my_dict[key] = model.wv.get_vector(key)
    # Or my_dict[key] = model.wv.word_vec(key, use_norm=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 my_dict = dict({})
# ----> 2 for idx, key in enumerate(vocab_cls.w2v.wv.vocab):
#       3     my_dict[key] = model.wv[key]
#
# File ~/miniconda3/lib/python3.9/site-packages/gensim/models/keyedvectors.py:661, in KeyedVectors.vocab(self)
#     659 @property
#     660 def vocab(self):
# --> 661     raise AttributeError(
#     662         "The vocab attribute was removed from KeyedVector in Gensim 4.0.0.\n"
#     663         "Use KeyedVector's .key_to_index dict, .index_to_key list, and methods "
#     664         ".get_vecattr(key, attr) and .set_vecattr(key, attr, new_val) instead.\n"
#     665         "See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4"
#     666     )
#
# AttributeError: The vocab attribute was removed from KeyedVector in Gensim 4.0.0.
# ...
